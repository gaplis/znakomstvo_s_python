# %% [markdown]
# # Практика
# К вам, как к аналитику, обратился ваш друг риэлтор и попросил написать программу, которая бы выводила стоимость квартиры в зависимости от введенной общей площади. Он дал вам файл с данными о стоимости одного квадратного метра в зависимости от площади квартир: https://disk.yandex.ru/d/v2BuPNXg2_y2-g. Помогите другу.

# %%
with open('data.csv', 'r', encoding='utf-8') as file:
    data = [s.split(',') for s in file.read().strip().split('\n')[1:]]

# print(*data, sep='\n')
xx = [float(s[0]) for s in data]
yy = [float(s[1]) for s in data]

# %%
import matplotlib.pyplot as plt
import numpy as np
fp, residuals, rank, sv, rcond = np.polyfit(xx, yy, 1, full=True)
k = fp[0]
b = fp[1]
new_y = [k*x + b for x in xx]
plt.scatter(xx, yy)
plt.xlabel('Метры')
plt.ylabel('Стоимость')
plt.plot(xx, new_y, 'r')
real_y = [-0.05 * x + 23 for x in xx]
plt.plot(xx, real_y, 'g')
plt.show()

# %%
x = 50
round((k*x+b)*x * 1000, 2)
# Out:
# 1023845.94

# %%
alfa1 = sum([x*y for x, y in zip(xx, yy)]) / len(xx)
alfa2 = sum([x**2 for  x in xx]) / len(xx)

avg_x = sum(xx) / len(xx)
avg_y = sum(yy) / len(yy)

alfa_k = (alfa1 - avg_x * avg_y) / (alfa2 - avg_x ** 2)
alfa_b = avg_y - alfa_k * avg_x

alfa_k, alfa_b
# Out:
# (-0.047835860169991286, 22.868711789443875)
